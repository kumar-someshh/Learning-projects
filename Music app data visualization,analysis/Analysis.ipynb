# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/MySpotifyDataTable.csv")
data.head()
# Out:
#    Unnamed: 0           endTime        artistName  \
# 0           0  2020-10-10 14:14     Sandip Ssingh
# 1           1  2020-10-10 14:14  Sukhwinder Singh
# 2           2  2020-10-10 14:18     Sandip Ssingh
# 3           3  2020-10-10 14:18  Sukhwinder Singh
# 4           4  2020-10-10 14:40    Suvarna Tiwari
#
#                      trackName  msPlayed  \
# 0                    Namo Namo     12390
# 1  Saugandh Mujhe Iss Mitti Ki      9416
# 2                    Namo Namo      3653
# 3  Saugandh Mujhe Iss Mitti Ki    235333
# 4                 Ishwar Allah     78476
#
#                                        UniqueID  In Library album track_uri
# 0                       Sandip Ssingh:Namo Namo           0   NaN       NaN
# 1  Sukhwinder Singh:Saugandh Mujhe Iss Mitti Ki           0   NaN       NaN
# 2                       Sandip Ssingh:Namo Namo           0   NaN       NaN
# 3  Sukhwinder Singh:Saugandh Mujhe Iss Mitti Ki           0   NaN       NaN
# ...

# %%
# prompt: Using dataframe data: How many time the song "Namo Namo " was played

data[data['trackName'] == 'Namo Namo ']['msPlayed'].sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737 entries, 0 to 736
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  737 non-null    int64
#  1   endTime     737 non-null    object
#  2   artistName  737 non-null    object
#  3   trackName   737 non-null    object
#  4   msPlayed    737 non-null    int64
#  5   UniqueID    737 non-null    object
#  6   In Library  737 non-null    int64
#  7   album       135 non-null    object
#  8   track_uri   135 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 51.9+ KB

# %% [markdown]
# Q. Which artist you listned the most? What are your top go to artist?

# %%
data["artistName"].value_counts()
# Out:
# artistName
# Imagine Dragons      77
# Maroon 5             44
# Alan Walker          40
# Taylor Swift         17
# Serhat Durmus        16
#                      ..
# Claire Rosinkranz     1
# Ariana Grande         1
# Trevor Daniel         1
# Jonas Brothers        1
# Guri                  1
# Name: count, Length: 254, dtype: int64

# %% [markdown]
# Q. Which song did you listen the most?

# %%
data["trackName"].value_counts( dropna = True, sort = True)
# Out:
# trackName
# Radioactive                    17
# Bad Liar                       14
# Thunder                        14
# Time - Alan Walker Remix       13
# Saugandh Mujhe Iss Mitti Ki    13
#                                ..
# Best 4 U                        1
# Faded                           1
# Don't Call Me Up                1
# Sucker                          1
# Treat You Better                1
# Name: count, Length: 440, dtype: int64

# %% [markdown]
# Q. Which song had the most play-time?

# %%
value = data["msPlayed"].max()
data[data["msPlayed"]== value]
# Out:
#      Unnamed: 0           endTime       artistName  \
# 702         702  2021-09-12 18:49  MEDITATION SELF
#
#                                              trackName  msPlayed  \
# 702   Focus Music,Reduce Anxiety, Increase Brain Po...   3589460
#
#                                               UniqueID  In Library album  \
# 702  MEDITATION SELF: Focus Music,Reduce Anxiety, I...           0   NaN
#
#     track_uri  minutesPlayed
# 702       NaN      59.824333

# %% [markdown]
# Q. which trackName was listned the most

# %%
# which trackName was listned the most

data.groupby('trackName')['msPlayed'].sum().idxmax()
# Out:
# 'Study Music, Concentration, Focus, Meditation, Memory, Work Music, Relaxing Music, Study, '

# %% [markdown]
# Q. How many minutes was the song "Namo Namo" was played?

# %%
data["minutesPlayed"] = data["msPlayed"].apply(lambda x: round(x / 60000, 2))

data
# Out:
#      Unnamed: 0           endTime        artistName  \
# 0             0  2020-10-10 14:14     Sandip Ssingh
# 1             1  2020-10-10 14:14  Sukhwinder Singh
# 2             2  2020-10-10 14:18     Sandip Ssingh
# 3             3  2020-10-10 14:18  Sukhwinder Singh
# 4             4  2020-10-10 14:40    Suvarna Tiwari
# ..          ...               ...               ...
# 732         732  2021-10-06 02:41       A.R. Rahman
# 733         733  2021-10-06 02:43    Sona Mohapatra
# 734         734  2021-10-06 02:43              Guri
# 735         735  2021-10-06 02:44       OneRepublic
# 736         736  2021-10-06 07:25      Shawn Mendes
#
#                        trackName  msPlayed  \
# 0                      Namo Namo     12390
# 1    Saugandh Mujhe Iss Mitti Ki      9416
# 2                      Namo Namo      3653
# 3    Saugandh Mujhe Iss Mitti Ki    235333
# 4                   Ishwar Allah     78476
# ..                           ...       ...
# ...

# %%
data[data['trackName'] == 'Namo Namo']['minutesPlayed'].sum()
# Out:
# 1.75

# %% [markdown]
# # understanding the genres table

# %%
genre_data = pd.read_csv("/content/GenresExpandedTable.csv")
genre_data.head()
# Out:
#    Unnamed: 0               track_uri              artist_uri           genres
# 0           0  5p7ujcrUXASCNwRaWNHR1C  26VFTg2z8YR0cCuwLzESi2       electropop
# 1           0  5p7ujcrUXASCNwRaWNHR1C  26VFTg2z8YR0cCuwLzESi2         etherpop
# 2           0  5p7ujcrUXASCNwRaWNHR1C  26VFTg2z8YR0cCuwLzESi2  indie poptimism
# 3           0  5p7ujcrUXASCNwRaWNHR1C  26VFTg2z8YR0cCuwLzESi2              pop
# 4           1  4uDhts78RdwIDjEqPrYVKp  7vk5e3vY1uw9plTHJAMwjN    electro house

# %% [markdown]
# Q. which geners you listend the most?

# %%
genre_data['genres'].value_counts().head(1)
# Out:
# genres
# pop    9
# Name: count, dtype: int64
